# %% [markdown]
# # Probability distribution problems

# %% [markdown]
# ## Binomial distribution
#
# In probability theory and statistics, the binomial distribution is the discrete probability distribution that gives only two possible results in an experiment, for example, when you flip a coin it can by either head or tails.

# %%
from scipy.stats import binom

# Define all the probability functions related to this distribution

def dbinom(x, size, prob = 0.5):
    """
    Calculates the point estimate of the binomial distribution
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calculates the cumulative of the binomial distribution
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calculates the quantile function from the binomial distribution
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Generates random variables from the binomial distribution
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Binomial(10, 0.2) distribution where n = 10 is the number of trials and p = 0.2 is the probability of success in a single trial.
import numpy as np
np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Exercise 1
#
# Write the above functions but for both normal and uniform distributions.

# %% [markdown]
# ## Normal Distribution

# %%
import scipy.stats as stats
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Parameters

# %%
#Parameters 
mu = 0  # Mean
sigma = 1  # Standar Deviation
step_size = 100

# Create a line to pass the function to normalize on the graph
data = np.linspace(-5, 5, step_size)

# %% [markdown]
# #We create the folowing functions:
#
# #### PDF
#
#     (PMF) Probability Mass Function - It does not have because its a continuous distribution
#         (PDF) Probability Density Function

# %%
def pdf_normal(x_values, loc=mu, scale=sigma):
    
    #Calcule the probability density function

    pdf = stats.norm.pdf(x_values, loc=mu, scale=sigma)
    return pdf

pdf_values_norm = pdf_normal(data, mu, sigma)

# Graphic the normal distribution
plt.figure(figsize = (10, 5))
plt.plot(data, pdf_values_norm, color= 'red')

# Personalizate the graphic
plt.title('Normal distribution')
plt.xlabel('Range')
plt.ylabel('Frequency')


# Show the histogram
plt.show()

# %% [markdown]
# #### CDF
#
#     (CDF) Cumulative Distribution Function

# %%
def cdf_normal(x_values, loc=mu, scale=sigma):

    #Calcule the cumulative distribution function

    cdf = stats.norm.cdf(x_values, loc=mu, scale=sigma)
    return cdf

cdf_values_norm = cdf_normal(data, mu, sigma)

# Graphic the normal distribution
plt.figure(figsize = (10, 5))
plt.plot(data, cdf_values_norm, color= 'red')

# Personalizate the graphic
plt.title('Cumulative distribution')
plt.xlabel('Range')
plt.ylabel('Frequency')


# Show the histogram
plt.show()

# %% [markdown]
# #### PPF
#
#     (PPF) Percentile Point Function

# %%
def ppf_normal(probability, mu, sigma):

    #Calcule the percentile point function

    ppf = stats.norm.ppf(probability, loc=mu, scale=sigma)
    return ppf

ppf_values_norm = ppf_normal(data, mu, sigma)


# Graphic the normal distribution
plt.figure(figsize = (10, 5))
plt.plot(data, ppf_values_norm, color= 'red')

# Personalizate the graphic
plt.title('Percentile distribution')
plt.xlabel('Range')
plt.ylabel('Frequency')


# Show the histogram
plt.show()

# %% [markdown]
# #### Random Normal Data

# %%
num_samples = 10000

random_normal_data = stats.norm.rvs(loc=mu, scale=sigma, size=num_samples)

# Graphic the normal distribution
plt.figure(figsize = (10, 5))
plt.hist(random_normal_data, bins=100, color='red', edgecolor='black')

# Personalizate the graphic
plt.title('Random Normal distribution')
plt.xlabel('Range')
plt.ylabel('Frequency')


# Show the histogram
plt.show()

# %% [markdown]
# ## Uniform Distribution

# %% [markdown]
# #### Parameters

# %%
#Parameters 
mu = 0  # Mean
sigma = 1  # Standar Deviation
step_size = 100

# Create a line to pass the function to normalize on the graph
data = np.linspace(-5, 5, step_size)

# %% [markdown]
# #We create the folowing functions:
#
# #### PDF
#
#     (PMF) Probability Mass Function - It does not have because its a continuous distribution
#         (PDF) Probability Density Function

# %% [markdown]
# ##### The uniform distribution function does not have a pdf because it is constant at all its points.

# %%
# Graphic the normal distribution
plt.figure(figsize = (10, 5))
plt.plot(data, x, color= 'red')

# Personalizate the graphic
plt.title('Normal distribution')
plt.xlabel('Range')
plt.ylabel('Frequency')


# Show the histogram
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/tr4shhh/Proyects/4geeks/05 - Random Variables/probability-distribution-exercises-project-with-python/notebook/problems.ipynb Cell 24 line 5
#       <a href='vscode-notebook-cell:/home/tr4shhh/Proyects/4geeks/05%20-%20Random%20Variables/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#X31sZmlsZQ%3D%3D?line=2'>3</a> # Graphic the normal distribution
#       <a href='vscode-notebook-cell:/home/tr4shhh/Proyects/4geeks/05%20-%20Random%20Variables/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#X31sZmlsZQ%3D%3D?line=3'>4</a> plt.figure(figsize = (10, 5))
# ...

# %%
import numpy as np

# Define the parameters of the range
a = 0  
b = 1  

#Create the random variables for uniform distribution
random_uniform_data = np.random.uniform(a, b, size=1000)  

# Graphic the uniform distribution
plt.hist(random_uniform_data, bins=100, color='skyblue', edgecolor='black')

# Personalizate the graphic
plt.title('Uniform distribution')
plt.xlabel('Range')
plt.ylabel('Frecuency')

# Show the histogram
plt.show()

# %% [markdown]
# #We create the folowing functions:
#
#     (PMF) Probability Mass Function - It does not have because its a continuous distribution
#         (PDF) Probability Density Function
#
#     (CDF) Cumulative Distribution Function
#
#     (PPF) Percentile Point Function

# %%
def uniform_pdf(x_values, a, b):

    #This PDF function means that the probability of X within [a, b] is the same
    # and outside that interval, the probability is zero.

    stats.uniform.pdf(x_values, loc=a, scale=b)
    
data_uniform_pdf = uniform_pdf(random_uniform_data, a, b)


def uniform_cdf(x_values, a, b):

    #the cumulative probability increases linearly from 0 to 1 as you go from a to b
    # and then remains constant at 1 for values greater than b.

    stats.uniform.cdf(x_values, loc=a, scale=b)

data_uniform_cdf = uniform_cdf(random_uniform_data, a, b)


def uniform_ppf(x_values, a, b):
    
    #The ppf allows you to find the value of the random variable
    #  that corresponds to a specific percentile or probability.

    stats.uniform.ppf(x_values, loc=a, scale=b)

data_uniform_ppf = uniform_ppf(random_uniform_data, a, b)
